# %% [markdown]
# # 使用Bokeh绘制向量场

# %% [markdown]
# Bokeh没有提供matplotlib中绘制向量场的函数`quiver()`。我们可以使用`segment()`绘制线段，每个向量箭头由4个点、三条线段绘制。

# %%
import numpy as np
from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5c6e3565-6c31-4840-9915-5778b5041f44">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# 下面的`make_quier()`计算向量场的各个箭头的坐标。其中`x`和`y`是每个箭头的起始坐标，`u`和`v`是箭头的方向和长短。当`scale_uv`为箭头长短的缩放系数，当值为`None`则自动将箭头缩放到箭头起始坐标之间的平均距离。`scale_arrow`为箭头部分占整体的比例，`theta`为箭头与箭杆之间的夹角。

# %%
def make_quiver(fig, x, y, u, v, scale_uv=None, scale_arrow=0.4, theta=20):
    x, y, u, v = (np.asanyarray(arr).ravel() for arr in (x, y, u, v))
    if scale_uv is None:
        from scipy.spatial.distance import pdist, squareform
        mean_dist = np.mean(np.sort(squareform(pdist(np.c_[x, y])), axis=1)[:, 1])
        max_len = np.max(np.hypot(u, v))
        scale_uv = mean_dist / max_len
        
    theta = np.deg2rad(theta)
    m1 = np.array([[np.cos(theta), np.sin(-theta)], [np.sin(theta), np.cos(theta)]])
    m2 = np.array([[np.cos(theta), np.sin(theta)], [np.sin(-theta), np.cos(theta)]])
    u, v = u * scale_uv, v * scale_uv
    uv = np.vstack([u, v])
    u1, v1 = m1 @ uv * scale_arrow
    u2, v2 = m2 @ uv * scale_arrow
    data = ColumnDataSource(data=dict(x0=x, y0=y, 
                                      x1=x+u, y1=y+v, 
                                      x2=x+u-u1, y2=y+v-v1, 
                                      x3=x+u-u2, y3=y+v-v2,
                                      u=u, v=v))
    fig.segment(x0="x0", y0="y0", x1="x1", y1="y1", source=data)
    fig.segment(x0="x1", y0="y1", x1="x2", y1="y2", source=data)
    fig.segment(x0="x1", y0="y1", x1="x3", y1="y3", source=data)
    return data

# %% [markdown]
# 下面是使用`make_quiver()`绘制向量场的一个例子：

# %%
a, b, c, d, k, r = 3.2, 0.6, 50, 0.56, 125, 1.6
X, Y = np.mgrid[0:80:10j, 0:80:10j]
U = r * X * (1 - X / k) - a * X * Y / (c + X)
V = b * a * X * Y / (c + X) - d * Y

fig = figure(plot_width=300, plot_height=300)
data = make_quiver(fig, X, Y, U, V)
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="975197af-b0a3-408b-83ca-090017798b8e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("975197af-b0a3-408b-83ca-090017798b8e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("975197af-b0a3-408b-83ca-090017798b8e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '975197af-b0a3-408b-83ca-090017798b8e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0d2819f7-42d7-45b7-8edd-3fd59094d4d4":{"roots":{"references":[{"attributes":{"overlay":{"id":"872029a2-4e12-4315-99a5-d868c8a1b5ab","type":"BoxAnnotation"},"plot":{"id":"0eccb808-984d-4e23-b958-8505eaab90d0","subtype":"Figure","type":"Plot"}},"id":"4155ea2f-c753-4e14-a42f-0155139aebf9","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x0":{"field":"x1"},"x1":{"field":"x3"},"y0":{"field":"y1"},"y1":{"field":"y3"}},"id":"9a4d529d-9a80-4a7c-89e4-f064198d6f5c","type":"Segment"},{"attributes":{},"id":"9a796d0a-52ce-4d04-accc-d6b6b86267e1","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"db14ea7b-32bd-4320-85c1-6ae5fc6b1a43","type":"BasicTickFormatter"},"plot":{"id":"0eccb808-984d-4e23-b958-8505eaab90d0","subtype":"Figure","type":"Plot"},"ticker":{"id":"b6191fda-db5f-44fa-b378-4165116aaf3f","type":"BasicTicker"}},"id":"318dba38-67de-40c1-b4e3-8fa124167e66","type":"LinearAxis"},{"attributes":{},"id":"8b7848f9-404f-4237-b7da-d35aabcdf050","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f82a52d5-e1dc-4778-bb33-4393004149f8","type":"PanTool"},{"id":"b0a7ef25-427c-481c-bc26-45f5460982c7","type":"WheelZoomTool"},{"id":"4155ea2f-c753-4e14-a42f-0155139aebf9","type":"BoxZoomTool"},{"id":"7bfaef11-35ba-4f8f-84c9-6ca0a0e07960","type":"SaveTool"},{"id":"87152990-eb83-427a-9bc0-bb8c20ef9708","type":"ResetTool"},{"id":"f3d39da2-5c91-4ebf-a34a-47a226428606","type":"HelpTool"}]},"id":"61be11bd-06d8-4781-95c1-23adec262a32","type":"Toolbar"},{"attributes":{"plot":{"id":"0eccb808-984d-4e23-b958-8505eaab90d0","subtype":"Figure","type":"Plot"}},"id":"87152990-eb83-427a-9bc0-bb8c20ef9708","type":"ResetTool"},{"attributes":{},"id":"b6191fda-db5f-44fa-b378-4165116aaf3f","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x0":{"field":"x0"},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"cfcf9758-3f48-402e-b404-b1d6f3b10c8e","type":"Segment"},{"attributes":{"plot":{"id":"0eccb808-984d-4e23-b958-8505eaab90d0","subtype":"Figure","type":"Plot"},"ticker":{"id":"660a4d68-5f2f-4c01-b00f-e3c520ea2c51","type":"BasicTicker"}},"id":"bac0cd98-945c-40da-af86-b07b5121cd6e","type":"Grid"},{"attributes":{"callback":null},"id":"fa04d4f9-8874-4261-a225-f4d60e47d108","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"285cb824-f6a2-4788-a778-d4c20c634ec9","type":"Title"},{"attributes":{"formatter":{"id":"9a796d0a-52ce-4d04-accc-d6b6b86267e1","type":"BasicTickFormatter"},"plot":{"id":"0eccb808-984d-4e23-b958-8505eaab90d0","subtype":"Figure","type":"Plot"},"ticker":{"id":"660a4d68-5f2f-4c01-b00f-e3c520ea2c51","type":"BasicTicker"}},"id":"0280e45a-7183-455b-b535-6f0607bc5b05","type":"LinearAxis"},{"attributes":{"plot":{"id":"0eccb808-984d-4e23-b958-8505eaab90d0","subtype":"Figure","type":"Plot"}},"id":"7bfaef11-35ba-4f8f-84c9-6ca0a0e07960","type":"SaveTool"},{"attributes":{"callback":null},"id":"7edb72ac-03e3-45c6-827d-62aa7a1ee86b","type":"DataRange1d"},{"attributes":{"line_color":{"value":"#1f77b4"},"x0":{"field":"x0"},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"feba9d0e-3e07-41e1-89c4-cad458b1fa86","type":"Segment"},{"attributes":{"plot":{"id":"0eccb808-984d-4e23-b958-8505eaab90d0","subtype":"Figure","type":"Plot"}},"id":"f3d39da2-5c91-4ebf-a34a-47a226428606","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["y2","y3","y1","y0","v","x1","u","x0","x2","x3"],"data":{"u":{"__ndarray__":"...","dtype":"float64","shape":[100]},"v":{"__ndarray__":"...","dtype":"float64","shape":[100]},"x0":{"__ndarray__":"...","dtype":"float64","shape":[100]},"x1":{"__ndarray__":"...","dtype":"float64","shape":[100]},"x2":{"__ndarray__":"...","dtype":"float64","shape":[100]},"x3":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y0":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y1":{"__n ...

# %% [markdown]
# 还可以使用`HoverTool`工具为每个箭头添加提示信息。

# %%
from bokeh.models.tools import HoverTool

fig = figure(plot_width=300, plot_height=300)
data = make_quiver(fig, X, Y, U, V)
hover = HoverTool(tooltips=[
    ("(x, y)", "@x0, @y0"),
    ("(u, v)", "@u, @v"),
])
fig.add_tools(hover)
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="adf8d89c-3900-4e7a-b8f8-7f79bd26ff57"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("adf8d89c-3900-4e7a-b8f8-7f79bd26ff57");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("adf8d89c-3900-4e7a-b8f8-7f79bd26ff57");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'adf8d89c-3900-4e7a-b8f8-7f79bd26ff57' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0639eab7-1e37-4a9d-b349-a42ca8784667":{"roots":{"references":[{"attributes":{"plot":{"id":"e7dc6a39-848b-4430-b89c-02417d04603f","subtype":"Figure","type":"Plot"}},"id":"ece6d417-4e9d-4a78-bcd2-4d8d54ba65c0","type":"HelpTool"},{"attributes":{"callback":null},"id":"3cae8bb8-7781-458a-b7a7-58490598f7e0","type":"DataRange1d"},{"attributes":{"formatter":{"id":"